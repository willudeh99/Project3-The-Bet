# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nba_stats = pd.read_csv("2020-2021_nba_stats.csv", encoding='latin1')

# %%
nba_stats.head()
# Out:
#   2020-2021 NBA Stats | Player Box Score & Advanced Metrics        Unnamed: 1  \
# 0                                               RANK                FULL NAME
# 1                                                NaN         Precious Achiuwa
# 2                                                NaN             Jaylen Adams
# 3                                                NaN             Steven Adams
# 4                                                NaN              Bam Adebayo
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0       TEAM        POS        AGE         GP        MPG
# 1        Mia          F      21.58         53       12.3
# 2        Mil          G      24.95          7        2.6
# 3        Nor          C      27.74         52         28
# 4        Mia        C-F      23.75         50       33.5
#
#                                           Unnamed: 7  \
# 0  MIN%Minutes PercentagePercentage of team minut...
# ...

# %%
header_row = 0
nba_stats.columns =nba_stats.iloc[header_row]

# %%
nba_stats
# Out:
# 0    RANK           FULL NAME  TEAM  POS    AGE  GP   MPG  \
# 0    RANK           FULL NAME  TEAM  POS    AGE  GP   MPG
# 1     NaN    Precious Achiuwa   Mia    F  21.58  53  12.3
# 2     NaN        Jaylen Adams   Mil    G  24.95   7   2.6
# 3     NaN        Steven Adams   Nor    C  27.74  52    28
# 4     NaN         Bam Adebayo   Mia  C-F  23.75  50  33.5
# ..    ...                 ...   ...  ...    ...  ..   ...
# 595   NaN          Trae Young   Atl    G  22.58  51  34.3
# 596   NaN         Cody Zeller   Cha  F-C  28.53  35  21.4
# 597   NaN         Ivica Zubac   Lac    C  24.08  58  22.2
# 598   NaN    Anthony Tolliver   Phi    F  35.88   1  14.1
# 599   NaN  Shaquille Harrison   Den    G  27.53   1   3.2
#
# 0   MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0    MIN%Minutes PercentagePercentage of team minut...
# 1                                                 25.6
# 2                                                  5.4
# ...

# %%
nba_stats = nba_stats.drop(0)
nba_stats
# Out:
# 0   RANK           FULL NAME TEAM  POS    AGE  GP   MPG  \
# 1    NaN    Precious Achiuwa  Mia    F  21.58  53  12.3
# 2    NaN        Jaylen Adams  Mil    G  24.95   7   2.6
# 3    NaN        Steven Adams  Nor    C  27.74  52    28
# 4    NaN         Bam Adebayo  Mia  C-F  23.75  50  33.5
# 5    NaN   LaMarcus Aldridge  San  C-F  35.75  21  25.9
# ..   ...                 ...  ...  ...    ...  ..   ...
# 595  NaN          Trae Young  Atl    G  22.58  51  34.3
# 596  NaN         Cody Zeller  Cha  F-C  28.53  35  21.4
# 597  NaN         Ivica Zubac  Lac    C  24.08  58  22.2
# 598  NaN    Anthony Tolliver  Phi    F  35.88   1  14.1
# 599  NaN  Shaquille Harrison  Den    G  27.53   1   3.2
#
# 0   MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 1                                                 25.6
# 2                                                  5.4
# 3                                                 58.3
# ...

# %%
nba_stats = nba_stats.groupby('TEAM')
nba_stats
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-188667f32e6e> in <module>
# ----> 1 nba_stats = nba_stats.groupby('TEAM')
#       2 nba_stats
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     579
#     580         raise AttributeError(
# --> 581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#     583
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'groupby'
